# %%
import pandas as pd
from pathlib import Path

data_path = Path('..') / 'data' / 'raw' / 'sample_feedback.csv'
df = pd.read_csv(data_path)
df.head()

# %%
# Class balance check
sentiment_counts = df['sentiment'].value_counts(normalize=True) * 100
emotion_counts = df['emotion'].value_counts(normalize=True) * 100

sentiment_counts.rename('sentiment_%').to_frame()

# %% [markdown]
# ## Next steps
# - Inspect longer real-world feedback before training.
# - Adjust preprocessing (stopwords, n-grams) based on domain.
# - Push cleaned splits to data/processed for reproducible runs.
